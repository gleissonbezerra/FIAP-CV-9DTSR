# %% [markdown]
# # 1. Introdução
#
# O Google possui uma biblioteca que consegue capturar até 468 pontos de ladmarks que permite que criar uma malha detalhada em 3D simulando mais precisamente uma representação virtual da face.

# %% [markdown]
# # 2. Instalar pacote mediapipe do GOOGLE

# %%
# !pip install mediapipe

# %%
! [ ! -d "/content/lena.png" ] && gdown -O /content/lena.png "16HLcddcqiAv92JsuJ0dbg9NKSz4D2dvj"

# %% [markdown]
# # 3. Exemplo

# %%
import cv2
import mediapipe as mp
from google.colab.patches import cv2_imshow

# Inicializar o módulo de Face Mesh do MediaPipe
mp_face_mesh = mp.solutions.face_mesh
mp_drawing = mp.solutions.drawing_utils

# Configurar desenho dos marcos
drawing_spec = mp_drawing.DrawingSpec(thickness=1, circle_radius=1)

with mp_face_mesh.FaceMesh(
    static_image_mode=False,
    max_num_faces=1,
    refine_landmarks=True,  # Inclui íris!
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
) as face_mesh:

  # TAREFA: Essa imagem não funciona. Sabe o motivo? Tente resolver? Pode testar com outras imagens.
  img = cv2.imread('lena.png')

  # Processar marcos faciais
  results = face_mesh.process(img)

  # Desenhar marcos na imagem original
  if results.multi_face_landmarks:
      for face_landmarks in results.multi_face_landmarks:
          mp_drawing.draw_landmarks(
              image=img,
              landmark_list=face_landmarks,
              connections=mp_face_mesh.FACEMESH_TESSELATION,
              landmark_drawing_spec=None,
              connection_drawing_spec=mp_drawing.DrawingSpec(color=(0,255,0), thickness=1)
          )

  cv2_imshow(img)
