# %% [markdown]
# # 1. Introdução
#
# OpenCV implementa um classificador em cascata Haar baseado Viola e Jones porém que permite extensão de features.

# %%
import cv2
from google.colab.patches import cv2_imshow
from pathlib import Path
from matplotlib import pyplot as plt
import numpy as np

# %%
! [ ! -d "/content/pessoas.jpg" ] && gdown -O /content/pessoas.jpg "19Q9M_vCwIxyUK4C45F2ZjRZcKUoBUugq"

! [ ! -d "/content/haarcascade_frontalcatface.xml" ] && gdown -O /content/haarcascade_frontalcatface.xml "1wXZTJRTKCsDGNl_7AbdFh979BMOTtrtv"

! [ ! -d "/content/cats_vs_dogs" ] && gdown -O /content/cats_vs_dogs.zip "1VuxwfbLZDXPt_0yKTauh4LRIhqMX1SdR" &&  unzip -q /content/cats_vs_dogs.zip -d /content && rm /content/cats_vs_dogs.zip

# %% [markdown]
# ## 2. Classificador Pré-Treinado

# %%
# Carregar o classificador treinado (pré-treinado para face frontal)
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Ler imagem
img = cv2.imread('pessoas.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detectar faces
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

# Desenhar retângulos
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

cv2_imshow(img)

# %%
# Carregar o classificador treinado (pré-treinado para face frontal)
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Ler imagem
img = cv2.imread('pessoas.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# TAREFA: Detectar faces corringindo o problema de falsos positviso
#faces =

# Desenhar retângulos
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

cv2_imshow(img)

# %% [markdown]
# ## 3. Classificador Personalizado

# %%
base_path = Path("/content/cats_vs_dogs")

test_images = [cv2.imread(str(p)) for p in (base_path/'train'/'cat').glob('000*.jpg')]

# %%
# escolhe aleatorimente uma imagem de inicio
start = np.random.randint(0, len(test_images)-8)
images = []

for i in range(0, 8):

  img = cv2.cvtColor(test_images[start+i], cv2.COLOR_BGR2RGB)

  # TAREFA: Carregar o classificador de face de gato (o arquivo haarcascade_frontalcatface.xml)
  #cat_face_cascade =

  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


  # TAREFA: Detectar faces de gato
  # cat_faces =

  # Desenhar as detecções
  for (x, y, w, h) in cat_faces:
      cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)


  images.append(img)

# Mostrar as imagens geradas
plt.figure(figsize=(16, 8))
for idx, img in enumerate(images):
    plt.subplot(2, 4, idx+1)
    plt.imshow(img)
    plt.axis('off')

plt.tight_layout()
plt.show()
